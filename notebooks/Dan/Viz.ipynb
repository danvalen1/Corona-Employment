# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import pandas as pd

module_path = os.path.abspath(os.path.join(os.pardir, os.pardir, 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from modules import VizFig as vf

images_dir = '../../src/images/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../../src/csv/employed_adults_apr2020_jul2020.csv')

# %%
viz.PlotCat(df, xvar='PESEX_x', targetdir=images_dir)

# %%
viz.PlotCat(df, xvar='PREMPNOT_y', targetdir=images_dir)

# %%
df.PREMPNOT_y.value_counts()
# Out:
# 1    3695
# 4     158
# 2     127
# 3       3
# Name: PREMPNOT_y, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
xvar='PREMPNOT_y'
kind='count'
palette='coolwarm'
dpi = 300
figsize = (5, 4)
fontscale = 1.2
sns.set(font_scale = fontscale, style = 'whitegrid')
markersize = 75

labels_dict = {'PESEX_x': 'Sex',
               'PREMPNOT_y': 'Employment Status'
              }

ticks_dict = {'PESEX_x': ['Male', 'Female'],
              'PREMPNOT_y': ['Employed', 'Unemployed', 'Not in Labor Force-Discouraged', 'Not in Labor Force-Other']
             }

title = f'Frequency of {labels_dict[xvar]} Categories'
    

fig = plt.figure(figsize=figsize, dpi=dpi)
sns.catplot(data=df,
                x=xvar,
                kind = kind,
                height = figsize[0],
                aspect = figsize[1]/figsize[0],
                palette=palette
               )
plt.xlabel(labels_dict[xvar])
plt.ylabel('Frequency')
plt.title(title)
labels = ticks_dict[xvar]
plt.xticks(list(range(len(labels))), [textwrap.fill(label, 10) for label in labels])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-079bd25bba43> in <module>()
#      36 plt.title(title)
#      37 labels = ticks_dict[xvar]
# ---> 38 plt.xticks(list(range(len(labels))), [textwrap.fill(label, 10) for label in labels])
#
# <ipython-input-107-079bd25bba43> in <listcomp>(.0)
#      36 plt.title(title)
#      37 labels = ticks_dict[xvar]
# ---> 38 plt.xticks(list(range(len(labels))), [textwrap.fill(label, 10) for label in labels])
#
# NameError: name 'textwrap' is not defined

# %%
df = pd.read_csv('../../src/csv/final_dataframe.csv')
df.head()
df.target.value_counts()
# Out:
# 0    3622
# 1     281
# Name: target, dtype: int64

# %%
vf.PlotCat(df, xvar='target', targetdir=images_dir)

# %%
vf.PlotCat(df, xvar='target', yvar='PEHRACTT', kind='violin', targetdir=images_dir)
